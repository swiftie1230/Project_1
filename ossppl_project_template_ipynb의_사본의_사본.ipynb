# %% [markdown]
# <a href="https://colab.research.google.com/github/swiftie1230/Project_1/blob/main/ossppl_project_template_ipynb%EC%9D%98_%EC%82%AC%EB%B3%B8%EC%9D%98_%EC%82%AC%EB%B3%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Open Source SW and Python Programming Project: Implementation of Subway Navigation**
#
# In this project, you will implement a navigation system for Seoul subway stations, especially **step by step**

# %% [markdown]
# # 0. Initialization
#
# Read subway station information by reading the file **simplified_subway_info_english.xlsx** or **simplified_subway_info_korean.xlsx**
# *  The excel file contains subway station information of Seoul subway line 1 ~ 4
# *  When you execute this sourcecode, you MUST upload these files in your Colab runtime environment
# *   **MUST NOT** change this code cell

# %%
import xlrd

# Read data file
data = xlrd.open_workbook("simplified_subway_info_english.xlsx")
data = data.sheet_by_name('Sheet1')

# Store the loaded book object as a string list in subwayStation variable
subwayStation = []
for line in range(4) :
    cur = [x for x in data.col_values(line) if x]    
    subwayStation.append(cur[1:])

# %% [markdown]
# # 1. Your implementation
# Let's start the implementation of a subway naviation system by using the loaded subway station information :)
#
# *   You can access the subway station information by referring to **subwayStation** variable (list type)

# %%
line = '**********************************************'
L1 = tuple(subwayStation[0])
L2 = tuple(subwayStation[1])
L3 = tuple(subwayStation[2])
L4 = tuple(subwayStation[3])
subwayStation = {'Line1' : L1 , 'Line2' : L2, 'Line3' : L3 , 'Line4' :L4}

import json

useraccount_file = "useraccount.json"

class User:
    def__init__(self, id, password, recent):
        self.id = id
        self.password = password
        self.recent = recent 
user = User()        
def load_user(filename = useraccount_file) :
  with open(filename, "r") as useraccount_json :
    return json.loads(useraccount_json.read()) 
def save_user(user, filename = useraccount_file):
  with open(filename, 'a') as useraccount_json:
    useraccount_json.write(json.dumps(user))
def add_user():
      
def disSubwayLineinfo() :
  print(line)
  print('Subway line information service')
  print(line)
  option_2 = None
  while option_2 not in subwayStation:
    try: 
      option_2 = str(input('>> Please enter a subway Line(Line1 ~ Line4): '))
    except TypeError:
      print('[Error] Invalid literal for int() with base 10:', option_2)
      print('Please enter a valid number')    
  print("You've selected", option_2)
  print('These are the subway stations in the subway line which you chose: ')
  print(subwayStation.get(option_2))
def disSubwayStationInfo() :
  print(line)
  print('Subway station information service')
  print(line)
  name = None 
  while name not in (L1+L2+L3+L4):
   name = str(input('>> Please enter a subway station name: '))
  if name in L1:
    if name in L2:
      if name in L3:
        if name in L4:
         print(name,'is in Line 1, 2, 3, and 4')
        else:
         print(name, 'is in Line 1, 2, and 3')  
      elif name in L4:
       print(name, 'is in Line 1, 2, and 4')
      else :
       print(name, 'is in Line 1, and 2')
    elif name in L3:
      if name in L4:
       print(name, 'is in Line 1, 3, and 4')
      else:
        print(name, 'is in Line 1, 3')
    elif name in L4:
      print(name, 'is in Line 1, and 4')   
    else:
      print(name, 'is in Line 1') 
  elif name in L2:
    if name in L3:
      if name in L4:
        print(name, 'is in Line 2, 3, and 4')
      else:
        print(name, 'is in Line 2, and 3') 
    elif name in L4:
      print(name, 'is in Line 2, and 4')
    else:
      print(name, 'is in Line 2')
  elif name in L3:
    if name in L4:
      print(name, 'is in Line 3, and 4')
    else:
      print(name, 'is in Line 3')    
  elif name in L4:
    print(name, 'is in Line 4')
def findPathSubwayInfo() :
  print(line)
  print('Navigation subway service')
  print(line)
  departure = None
  arrival = None
  while (departure or arrival) not in (L1+L2+L3+L4):
    departure = str(input('>> Please enter your departure subway station: '))
    arrival = str(input('>>Please enter your arrival subway station: '))
    user.recent = departure, arrival
  print("Your departure subway station is", departure ,"and your arrival subway station is", arrival)
  if departure in L1:
   if arrival in L1:
    if L1.index(departure) <= L1.index(arrival):
     print(L1[(L1.index(departure)):(L1.index(arrival))])
    else:
     print(L1[L1.index(departure):],L1[:L1.index(arrival)])
   elif arrival in L2:
    if L1.index(departure) <= 32:
      if L2.index(arrival) >= 33:
       print(L1[(L1.index(departure)):31], L2[33:(L2.index(arrival))])
      else:
       print(L1[(L1.index(departure)):31], L2[33:], L2[:L2.index(arrival)])
    else:
      if L2.index(arrival) >= 33:
       print(L1[(L1.index(departure)):], L1[:31], L2[33:(L2.index(arrival))])
      else:
       print(L1[(L1.index(departure)):], L1[:31], L2[33:], L2[:L2.index(arrival)])
   elif arrival in L3:    
    if L1.index(departure) <= 30:
      if L3.index(arrival) >= 20:
       print(L1[(L1.index(departure)):29], L3[20:(L3.index(arrival))])
      else:
       print(L1[(L1.index(departure)):29], L3[20:], L3[:L3.index(arrival)])
    else:
      if L3.index(arrival) >= 20:
       print(L1[(L1.index(departure)):], L1[:29], L3[20:(L3.index(arrival))])
      else:
       print(L1[(L1.index(departure)):], L1[:29], L3[20:], L3[:L3.index(arrival)]) 
   elif arrival in L4:  
     if L1.index(departure) <= 33:
      if L4.index(arrival) >= 17:
       print(L1[(L1.index(departure)):32], L4[17:(L4.index(arrival))])
      else:
       print(L1[(L1.index(departure)):32], L4[17:], L4[:L4.index(arrival)])
     else:
      if L4.index(arrival) >= 17:
       print(L1[(L1.index(departure)):], L1[:32], L4[17:(L4.index(arrival))])
      else:
       print(L1[(L1.index(departure)):], L1[:32], L4[17:], L4[:L4.index(arrival)])
  elif departure in L2:
   if arrival in L2:
    if L2.index(departure) <= L2.index(arrival):
     print(L2[(L2.index(departure)):(L2.index(arrival))])
    else:
     print(L2[L2.index(departure):],L2[:L2.index(arrival)])
   elif arrival in L1:
    if L2.index(departure) <= 33:
      if L1.index(arrival) >= 32:
       print(L2[(L2.index(departure)):32], L1[32:(L1.index(arrival))])
      else:
       print(L2[(L2.index(departure)):32], L1[32:], L1[:L1.index(arrival)])
    else:
      if L1.index(arrival) >= 32:
       print(L2[(L2.index(departure)):], L2[:32], L1[32:(L1.index(arrival))])
      else:
       print(L2[(L2.index(departure)):], L2[:32], L1[32:], L1[:L1.index(arrival)])
   elif arrival in L3:    
    if L2.index(departure) <= 31:
      if L3.index(arrival) >= 21:
       print(L2[(L2.index(departure)):30], L3[21:(L3.index(arrival))])
      else:
       print(L2[(L2.index(departure)):30], L3[21:], L3[:L3.index(arrival)])
    else:
      if L3.index(arrival) >= 21:
       print(L2[(L2.index(departure)):], L2[:30], L3[21:(L3.index(arrival))])
      else:
       print(L2[(L2.index(departure)):], L2[:30], L3[21:], L3[:L3.index(arrival)]) 
   elif arrival in L4:  
     if L2.index(departure) <= 8:
      if L4.index(arrival) >= 24:
       print(L2[(L2.index(departure)):7], L4[24:(L4.index(arrival))])
      else:
       print(L2[(L2.index(departure)):7], L4[24:], L4[:L4.index(arrival)])
     else:
      if L4.index(arrival) >= 24:
       print(L2[(L2.index(departure)):], L2[:7], L4[24:(L4.index(arrival))])
      else:
       print(L2[(L2.index(departure)):], L2[:7], L4[24:], L4[:L4.index(arrival)])   
  elif departure in L3:
   if arrival in L3:
    if L3.index(departure) <= L3.index(arrival):
     print(L3[(L3.index(departure)):(L3.index(arrival))])
    else:
     print(L3[L3.index(departure):],L3[:L3.index(arrival)])
   elif arrival in L1:
    if L3.index(departure) <= 20:
      if L1.index(arrival) >= 30:
       print(L3[(L3.index(departure)):19], L1[30:(L1.index(arrival))])
      else:
       print(L3[(L3.index(departure)):19], L1[30:], L1[:L1.index(arrival)])
    else:
      if L1.index(arrival) >= 30:
       print(L3[(L3.index(departure)):], L3[:19], L1[30:(L1.index(arrival))])
      else:
       print(L3[(L3.index(departure)):], L3[:19], L1[30:], L1[:L1.index(arrival)])
   elif arrival in L2:    
    if L3.index(departure) <= 21:
      if L2.index(arrival) >= 31:
       print(L3[(L3.index(departure)):20], L2[31:(L2.index(arrival))])
      else:
       print(L3[(L3.index(departure)):20], L2[31:], L2[:L2.index(arrival)])
    else:
      if L2.index(arrival) >= 31:
       print(L3[(L3.index(departure)):], L3[:20], L2[31:(L2.index(arrival))])
      else:
       print(L3[(L3.index(departure)):], L3[:20], L2[31:], L2[:L2.index(arrival)]) 
   elif arrival in L4:  
     if L3.index(departure) <= 22:
      if L4.index(arrival) >= 14:
       print(L3[(L3.index(departure)):21], L4[14:(L4.index(arrival))])
      else:
       print(L3[(L3.index(departure)):21], L4[14:], L4[:L4.index(arrival)])
     else:
      if L4.index(arrival) >= 14:
       print(L3[(L3.index(departure)):], L3[:21], L4[14:(L4.index(arrival))])
      else:
       print(L3[(L3.index(departure)):], L3[:21], L4[14:], L4[:L4.index(arrival)])
  elif departure in L4:
   if arrival in L4:
    if L4.index(departure) <= L4.index(arrival):
     print(L4[(L4.index(departure)):(L4.index(arrival))])
    else:
     print(L4[L4.index(departure):],L4[:L4.index(arrival)])
   elif arrival in L1:
    if L4.index(departure) <= 17:
      if L1.index(arrival) >= 33:
       print(L4[(L4.index(departure)):16], L1[33:(L1.index(arrival))])
      else:
       print(L4[(L4.index(departure)):16], L1[33:], L1[:L1.index(arrival)])
    else:
      if L1.index(arrival) >= 33:
       print(L4[(L4.index(departure)):], L4[:16], L1[33:(L1.index(arrival))])
      else:
       print(L4[(L4.index(departure)):], L4[:16], L1[33:], L1[:L1.index(arrival)])
   elif arrival in L2:    
    if L4.index(departure) <= 24:
      if L2.index(arrival) >= 8:
       print(L4[(L4.index(departure)):23], L2[8:(L2.index(arrival))])
      else:
       print(L4[(L4.index(departure)):23], L2[8:], L2[:L2.index(arrival)])
    else:
      if L2.index(arrival) >= 8:
       print(L4[(L4.index(departure)):], L4[:23], L2[8:(L2.index(arrival))])
      else:
       print(L4[(L4.index(departure)):], L4[:23], L2[8:], L2[:L2.index(arrival)]) 
   elif arrival in L3:  
     if L4.index(departure) <= 14:
      if L3.index(arrival) >= 22:
       print(L4[(L4.index(departure)):13], L3[22:(L3.index(arrival))])
      else:
       print(L4[(L4.index(departure)):13], L3[22:], L3[:L3.index(arrival)])
     else:
      if L3.index(arrival) >= 22:
       print(L4[(L4.index(departure)):], L4[:13], L3[22:(L3.index(arrival))])
      else:
       print(L4[(L4.index(departure)):], L4[:13], L3[22:], L3[:L3.index(arrival)])  
   
print(line)
print('1. Log in (or sign up)')
print('2. Exit')
print(line)
option_0 = None
while option_0 not in range(1, 3):
  option_0 = int(input('Please choose one of the options (1 - 2): '))
if option_0 == 1 :
   print(line)
   print('Log in (or sign up)')
   print(line)
   username = str(input('Please enter username: '))
   password = int(input('Please enter password: '))
   while !(password == user.password):
     print('Password is incorrect')
     username = str(input('Please enter username: '))
     password = int(input('Please enter password: '))
     newuser = User(username, password,)
     if username not in useraccount_file:
       save_user(user)
       print('Your account (', username, ') has been successfully created')
       break
     elif username in useraccount_file:
       break
   print(line)
   print('Welcome,', username)
 elif option_0 == 2 :
   print('Program ended. Thank you for using our program.')  
print(line)
print('1. Display subway line information(Line 1 ~ 4)')
print('2. Display subway station information')
print('3. Find a path between two subway stations')
print('4. View my recent requests')
print('5. Exit')
print(line)
option_1 = None
while not (option_1 == 5) :
 option_1 = int(input('Please choose one of the options: '))
 if option_1 not in range(1, 6):
  continue
 elif option_1 == 1 :
  disSubwayLineinfo()
  continue
 elif option_1 == 2 :
  disSubwayStationInfo()
  continue
 elif option_1 == 3 :
   findPathSubwayInfo()
   continue
 elif option_1 == 4 :
   print(line)
   print(My recent request service)
   print(line)
   if (user.recent == None):
     print('There is no previous request')
   else:
     print('Your most recent navigaiton request:')
     print('1.'departure, 'to', arrival)
     print('Go back')
     option = None
     option = int(input('Please choose one of options(1 - 2): '))  
     if (option == 1):
       print(user.recent)
     elif(option == 2):
       break
   continue

   
else :
  print('Program ended. Thank you for using our program.')
# Out:
#   File "<ipython-input-3-6d1f35b541ed>", line 13
#     def__init__(self, id, password, recent):
#                                             ^
# SyntaxError: invalid syntax
